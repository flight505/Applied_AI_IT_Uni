# %% [markdown]
# # Convolutional Neural Networsk Project

# %% [markdown]
# ## Sub-project 1:
#
# ## Solve Fashion_MNIST with LeNet architecture
#
# In this project you will implement the LeNet architecture of Convolutional Neural Networks. First you will download the Fashion-MNIST dataset. Split into train/validation/test datasets and train the network. Finally, plot the learning curves (train/validation loss and accuracy) and show the confusion matrix.

# %% [markdown]
# ### 1. Download Fashion-MNIST

# %%
import numpy as np # to handle matrix and data operation
import pandas as pd # to read csv and handle dataframe
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data
from torch.autograd import Variable
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
from torch import optim
import tensorflow as tf
import keras
import keras.layers as layers
from keras.models import Sequential
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.callbacks import TensorBoard
from keras.datasets import mnist
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 2. Split the data into train / validation / test subsets. Make mini-batches, if necesssary.

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
 
# Enter data as mnist data set
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# normalizing
x_train = x_train / 255
x_test = x_test / 255
 
y_train = keras.utils.np_utils.to_categorical(y_train, 10)
y_test = keras.utils.np_utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1)

# %%
# Test if the shapes are correct and the values make sense
print("x_train shape: " + str(x_train.shape))
print("y_train shape: " + str(y_train.shape))
print("x_val shape: " + str(x_val.shape))
print("y_val shape: " + str(y_val.shape))
print("x_test shape: " + str(x_test.shape))
print("y_test shape: " + str(y_test.shape))
# Out:
# x_train shape: (54000, 28, 28, 1)
# y_train shape: (54000, 10)
# x_val shape: (6000, 28, 28, 1)
# y_val shape: (6000, 10)
# x_test shape: (10000, 28, 28, 1)
# y_test shape: (10000, 10)

# %% [markdown]
# ### 3. Build the LeNet model

# %%
# The LeNet model is build in Keras

model = keras.Sequential()

model.add(layers.Conv2D(filters=6, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.AveragePooling2D())

model.add(layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model.add(layers.AveragePooling2D())

model.add(layers.Flatten())

model.add(layers.Dense(units=120, activation='relu'))

model.add(layers.Dense(units=84, activation='relu'))

model.add(layers.Dense(units=10, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 6)         60
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 13, 13, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 16)        880
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 60,074
# Trainable params: 60,074
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 4. Train the model on the dataset

# %%
model.compile(loss=keras.metrics.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# Fitting the model
n_EPOCHS = 100

history = model.fit(x_train, y_train, batch_size=128, epochs=n_EPOCHS, verbose=1, validation_data=(x_val, y_val))
score = model.evaluate(x_test, y_test)
print('Val Loss:', score[0])
print('Val accuracy:', score[1])
# Out:
# Epoch 1/100
# 422/422 [==============================] - 19s 7ms/step - loss: 1.0239 - accuracy: 0.6451 - val_loss: 0.5297 - val_accuracy: 0.8052
# Epoch 2/100
# 422/422 [==============================] - 2s 5ms/step - loss: 0.5028 - accuracy: 0.8119 - val_loss: 0.4657 - val_accuracy: 0.8293
# Epoch 3/100
# 422/422 [==============================] - 2s 5ms/step - loss: 0.4305 - accuracy: 0.8432 - val_loss: 0.4211 - val_accuracy: 0.8498
# Epoch 4/100
# 422/422 [==============================] - 2s 5ms/step - loss: 0.4011 - accuracy: 0.8521 - val_loss: 0.3883 - val_accuracy: 0.8637
# Epoch 5/100
# 422/422 [==============================] - 2s 5ms/step - loss: 0.3722 - accuracy: 0.8650 - val_loss: 0.3829 - val_accuracy: 0.8628
# Epoch 6/100
# 422/422 [==============================] - 2s 5ms/step - loss: 0.3530 - accuracy: 0.8745 - val_loss: 0.3578 - val_accuracy: 0.8702
# Epoch 7/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0
100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0411 - accuracy: 0.9849 - val_loss: 0.5556 - val_accuracy: 0.8993
# Epoch 83/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0394 - accuracy: 0.9858 - val_loss: 0.5734 - val_accuracy: 0.9005
# Epoch 84/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0521 - accuracy: 0.9801 - val_loss: 0.5886 - val_accuracy: 0.8988
# Epoch 85/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0471 - accuracy: 0.9823 - val_loss: 0.6034 - val_accuracy: 0.8980
# Epoch 86/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0474 - accuracy: 0.9819 - val_loss: 0.5911 - val_accuracy: 0.9013
# Epoch 87/100
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0421 - accuracy: 0.9845 - val_loss: 0.5830 - val_accuracy: 0.9032
# Epoch 88/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0402 - accuracy: 0.9851 - val_loss: 0.5890 - val_accuracy: 0.9018
# Epoch 89/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0330 - accuracy: 0.9881 - val_loss: 0.6268 - val_accuracy: 0.9030
# Epoch 90/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0407 - accuracy: 0.9851 - val_loss: 0.6285 - val_accuracy: 0.8948
# Epoch 91/100
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0386 - accuracy: 0.9861 - val_loss: 0.6354 - val_accuracy: 0.9012
# Epoch 92/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0401 - accuracy: 0.9849 - val_loss: 0.6213 - val_accuracy: 0.8987
# Epoch 93/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0352 - accuracy: 0.9872 - val_loss: 0.6376 - val_accuracy: 0.9003
# Epoch 94/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0356 - accuracy: 0.9870 - val_loss: 0.6681 - val_accuracy: 0.8983
# Epoch 95/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0353 - accuracy: 0.9874 - val_loss: 0.6697 - val_accuracy: 0.8993
# Epoch 96/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0382 - accuracy: 0.9850 - val_loss: 0.6583 - val_accuracy: 0.8977
# Epoch 97/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0373 - accuracy: 0.9857 - val_loss: 0.6570 - val_accuracy: 0.8933
# Epoch 98/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0376 - accuracy: 0.9870 - val_loss: 0.6641 - val_accuracy: 0.8992
# Epoch 99/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0336 - accuracy: 0.9877 - val_loss: 0.6822 - val_accuracy: 0.8998
# Epoch 100/100
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0279 - accuracy: 0.9902 - val_loss: 0.6798 - val_accuracy: 0.9005
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7214 - accuracy: 0.8945
# Val Loss: 0.7214388847351074
# Val accuracy: 0.8945000171661377

# %% [markdown]
# ### 5. Plot the training curves (Loss and accuracy)

# %%
# Training history
_, axes = plt.subplots(2, 1, sharex=True)
# ax1.ylabel('training error')
# ax1.xlabel('epoch')
for ax, k in zip(axes, history.history.keys()):
    ax.set_ylabel(k)
    ax.set_xlabel("Epoch")
    ax.plot(history.history[k], label = k)
# plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ### 6. Show the confusion matrix and accuracy on the test dataset.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred=model(x_test)
y_pred=np.argmax(y_pred, axis=1)

y_test=np.argmax(y_test, axis=1)
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True)

# %%
# the accuracy is found
from sklearn import metrics

accuracy = metrics.accuracy_score(y_test, y_pred)
print("The accuracy of the model is: ", accuracy)
# Out:
# The accuracy of the model is:  0.8945

# %% [markdown]
# ### 7. Is LeNet better than the fully connected Neural Network trained in the project from lecture 3? Comment on the results

# %% [markdown]
# Answer:

# %% [markdown]
# ## Sub-project 2:
#
# ## Use a pretrained model to solve
#
# In this project you will download the Intel Image Classification dataset (https://www.kaggle.com/puneet6060/intel-image-classification/download).
# Find a suitable pretrained Convolutional Neural Network and its weights. Fix the filters and retrain/finetune the top of the network. Show and comment on resuls.
#
# Alternativelly, you can browse Kaggle for some funny datasets like: Dogs vs Cats, Alien vs Predator, Doom vs Animal Crossing, CelebA, etc. Just don't use something easy like MNIST, Fashion-MNIST, etc.

# %% [markdown]
# ### 1. Download the data

# %%
import tensorflow_datasets as tfds
train_ds, validation_ds, test_ds = tfds.load(
  "horses_or_humans",
  # Reserve 10% for validation and 10% for test
  split=["train[:40%]", "train[40%:50%]", "train[50%:60%]"],
  as_supervised=True,  # Include labels
)


test_labels = list()
for image, label in test_ds.as_numpy_iterator():
  test_labels.append(label)
  
print(f"# training samples: {tf.data.experimental.cardinality(train_ds)}")
print(f"# validation samples: {tf.data.experimental.cardinality(validation_ds)}")
print(f"# test samples: {tf.data.experimental.cardinality(test_ds)}")
# Out:
# Downloading and preparing dataset horses_or_humans/3.0.0 (download: 153.59 MiB, generated: Unknown size, total: 153.59 MiB) to /root/tensorflow_datasets/horses_or_humans/3.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/horses_or_humans/3.0.0.incompleteTGPUQW/horses_or_humans-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=1027.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/horses_or_humans/3.0.0.incompleteTGPUQW/horses_or_humans-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=256.0), HTML(value='')))
# Dataset horses_or_humans downloaded and prepared to /root/tensorflow_datasets/horses_or_humans/3.0.0. Subsequent calls will reuse this data.
# # training samples: 411
# # validation samples: 103
# # test samples: 102

# %%
# The data is visualized

plt.figure(figsize=(10, 10))
for i, (image, label) in enumerate(train_ds.take(9)):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(image)
  plt.title(int(label))
  plt.axis('on')
  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# ### 2. Preprocess the data.
#
# (This might include resizing, augmenting, etc.)

# %%
# Resize data
size = (150, 150)
train_ds = train_ds.map(lambda x, y: (tf.image.resize(x, size), y))
validation_ds = validation_ds.map(lambda x, y: (tf.image.resize(x, size), y))
test_ds = test_ds.map(lambda x, y: (tf.image.resize(x, size), y))

# Batch data
batch_size = 32

train_ds = train_ds.cache().batch(batch_size).prefetch(buffer_size=10)
validation_ds = validation_ds.cache().batch(batch_size).prefetch(buffer_size=10)
test_ds = test_ds.cache().batch(batch_size).prefetch(buffer_size=10)

# %%
# The data is augmented in order to make it more representative
data_augmentation = keras.Sequential(
  [
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
  ])

import numpy as np

for images, labels in train_ds.take(1):
  plt.figure(figsize=(10, 10))
  first_image = images[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(
      tf.expand_dims(first_image, 0), training=True
    )
    plt.imshow(augmented_image[0].numpy().astype("int32"))
    plt.axis("off")

# %% [markdown]
# ### 3. Split the data (train / test / validation) and make mini-batches.

# %% [markdown]
# ### 4. Download the pretrained architecture and weights.
#
# This part might include some research and understanding of architecures and the type of data they were trained on.

# %%
class MyModel(tf.keras.Model):
  def __init__(self):
    super(MyModel, self).__init__()
    self.dense1 = tf.keras.layers.Dense(4, activation=tf.nn.relu)
    self.dense2 = tf.keras.layers.Dense(5, activation=tf.nn.softmax)
 
  def call(self, inputs):
    x = self.dense1(inputs)
    return self.dense2(x)
 
model = MyModel()

# %%
# "which network should I steal from the internet"

base_model = tf.keras.applications.Xception(
  weights="imagenet",  # Load weights pre-trained on ImageNet.
  input_shape=(150, 150, 3),
  include_top=False, # Do not include the ImageNet classifier at the top.
)  

# Freeze the base_model
base_model.trainable = False

# Create new model on top
inputs = keras.Input(shape=(150, 150, 3))
# Apply random data augmentation
# In this case, we will just disturb the already existing data
x = data_augmentation(inputs)

# Pre-trained Xception weights requires that input be normalized
# from (0, 255) to a range (-1., +1.)
# The normalization layer does the following:
#            outputs = (inputs - mean) / sqrt(var)
norm_layer = tf.keras.layers.experimental.preprocessing.Normalization()
mean = np.array([127.5] * 3)
var = mean ** 2
# Scale inputs to [-1, +1]
x = norm_layer(x)
norm_layer.set_weights([mean, var])

# The base model is not supposed to train, so we will put it into inference mode
#    `training=False`
x = base_model(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
outputs = keras.layers.Dense(1)(x)
model = keras.Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution), but
# are not present in its tracked objects:
#   <tf.Variable 'block1_conv1/kernel:0' shape=(3, 3, 3, 32) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution), but
# are not present in its tracked objects:
#   <tf.Variable 'block1_conv1/kernel:0' shape=(3, 3, 3, 32) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm), but
# are not present in its tracked objects:
#   <tf.Variable 'block1_conv1_bn/gamma:0' shape=(32,) dtype=float32>
#   <tf.Variable 'block1_conv1_bn/beta:0' shape=(32,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm), but
# are not present in its tracked objects:
#   <tf.Variable 'block1_conv1_bn/gamma:0' shape=(32,) dtype=float32>
#   <tf.Variable 'block1_conv1_bn/beta:0' shape=(32,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_1), but
# are not present in its tracked objects:
#   <tf.Variable 'block1_conv2/kernel:0' shape=(3, 3, 32, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_1), but
# are not present in its tracked objects:
#   <tf.Variable 'block1_conv2/kernel:0' shape=(3, 3, 32, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_1), but
# are not present in its tracked objects:
#   <tf.Variable 'block1_conv2_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'block1_conv2_bn/beta:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_1), but
# are not present in its tracked objects:
#   <tf.Variable 'block1_conv2_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'block1_conv2_bn/beta:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d), but
# are not present in its tracked objects:
#   <tf.Variable 'block2_sepconv1/depthwise_kernel:0' shape=(3, 3, 64, 1) dtype=float32>
#   <tf.Variable 'block2_sepconv1/pointwise_kernel:0' shape=(1, 1, 64, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d), but
# are not present in its tracked objects:
#   <tf.Variable 'block2_sepconv1/depthwise_kernel:0' shape=(3, 3, 64, 1) dtype=float32>
#   <tf.Variable 'block2_sepconv1/pointwise_kernel:0' shape=(1, 1, 64, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_2), but
# are not present in its tracked objects:
#   <tf.Variable 'block2_sepconv1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'block2_sepconv1_bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_2), but
# are not present in its tracked objects:
#   <tf.Variable 'block2_sepconv1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'block2_sepconv1_bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_1), but
# are not present in its tracked objects:
#   <tf.Variable 'block2_sepconv2/depthwise_kernel:0' shape=(3, 3, 128, 1) dtype=float32>
#   <tf.Variable 'block2_sepconv2/pointwise_kernel:0' shape=(1, 1, 128, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_1), but
# are not present in its tracked objects:
#   <tf.Variable 'block2_sepconv2/depthwise_kernel:0' shape=(3, 3, 128, 1) dtype=float32>
#   <tf.Variable 'block2_sepconv2/pointwise_kernel:0' shape=(1, 1, 128, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_2), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2d/kernel:0' shape=(1, 1, 64, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_2), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2d/kernel:0' shape=(1, 1, 64, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_3), but
# are not present in its tracked objects:
#   <tf.Variable 'block2_sepconv2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'block2_sepconv2_bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_3), but
# are not present in its tracked objects:
#   <tf.Variable 'block2_sepconv2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'block2_sepconv2_bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_4), but
# are not present in its tracked objects:
#   <tf.Variable 'batch_normalization/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'batch_normalization/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_4), but
# are not present in its tracked objects:
#   <tf.Variable 'batch_normalization/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'batch_normalization/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_2), but
# are not present in its tracked objects:
#   <tf.Variable 'block3_sepconv1/depthwise_kernel:0' shape=(3, 3, 128, 1) dtype=float32>
#   <tf.Variable 'block3_sepconv1/pointwise_kernel:0' shape=(1, 1, 128, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_2), but
# are not present in its tracked objects:
#   <tf.Variable 'block3_sepconv1/depthwise_kernel:0' shape=(3, 3, 128, 1) dtype=float32>
#   <tf.Variable 'block3_sepconv1/pointwise_kernel:0' shape=(1, 1, 128, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_5), but
# are not present in its tracked objects:
#   <tf.Variable 'block3_sepconv1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'block3_sepconv1_bn/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_5), but
# are not present in its tracked objects:
#   <tf.Variable 'block3_sepconv1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'block3_sepconv1_bn/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_3), but
# are not present in its tracked objects:
#   <tf.Variable 'block3_sepconv2/depthwise_kernel:0' shape=(3, 3, 256, 1) dtype=float32>
#   <tf.Variable 'block3_sepconv2/pointwise_kernel:0' shape=(1, 1, 256, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_3), but
# are not present in its tracked objects:
#   <tf.Variable 'block3_sepconv2/depthwise_kernel:0' shape=(3, 3, 256, 1) dtype=float32>
#   <tf.Variable 'block3_sepconv2/pointwise_kernel:0' shape=(1, 1, 256, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_3), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2d_1/kernel:0' shape=(1, 1, 128, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_3), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2d_1/kernel:0' shape=(1, 1, 128, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_6), but
# are not present in its tracked objects:
#   <tf.Variable 'block3_sepconv2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'block3_sepconv2_bn/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_6), but
# are not present in its tracked objects:
#   <tf.Variable 'block3_sepconv2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'block3_sepconv2_bn/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_7), but
# are not present in its tracked objects:
#   <tf.Variable 'batch_normalization_1/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'batch_normalization_1/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_7), but
# are not present in its tracked objects:
#   <tf.Variable 'batch_normalization_1/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'batch_normalization_1/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_4), but
# are not present in its tracked objects:
#   <tf.Variable 'block4_sepconv1/depthwise_kernel:0' shape=(3, 3, 256, 1) dtype=float32>
#   <tf.Variable 'block4_sepconv1/pointwise_kernel:0' shape=(1, 1, 256, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_4), but
# are not present in its tracked objects:
#   <tf.Variable 'block4_sepconv1/depthwise_kernel:0' shape=(3, 3, 256, 1) dtype=float32>
#   <tf.Variable 'block4_sepconv1/pointwise_kernel:0' shape=(1, 1, 256, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_8), but
# are not present in its tracked objects:
#   <tf.Variable 'block4_sepconv1_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block4_sepconv1_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_8), but
# are not present in its tracked objects:
#   <tf.Variable 'block4_sepconv1_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block4_sepconv1_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_5), but
# are not present in its tracked objects:
#   <tf.Variable 'block4_sepconv2/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block4_sepconv2/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_5), but
# are not present in its tracked objects:
#   <tf.Variable 'block4_sepconv2/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block4_sepconv2/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_4), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2d_2/kernel:0' shape=(1, 1, 256, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_4), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2d_2/kernel:0' shape=(1, 1, 256, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_9), but
# are not present in its tracked objects:
#   <tf.Variable 'block4_sepconv2_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block4_sepconv2_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_9), but
# are not present in its tracked objects:
#   <tf.Variable 'block4_sepconv2_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block4_sepconv2_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_10), but
# are not present in its tracked objects:
#   <tf.Variable 'batch_normalization_2/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'batch_normalization_2/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_10), but
# are not present in its tracked objects:
#   <tf.Variable 'batch_normalization_2/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'batch_normalization_2/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_6), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv1/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block5_sepconv1/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_6), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv1/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block5_sepconv1/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_11), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv1_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block5_sepconv1_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_11), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv1_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block5_sepconv1_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_7), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv2/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block5_sepconv2/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_7), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv2/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block5_sepconv2/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_12), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv2_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block5_sepconv2_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_12), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv2_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block5_sepconv2_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_8), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv3/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block5_sepconv3/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_8), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv3/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block5_sepconv3/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_13), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv3_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block5_sepconv3_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_13), but
# are not present in its tracked objects:
#   <tf.Variable 'block5_sepconv3_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block5_sepconv3_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_9), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv1/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block6_sepconv1/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_9), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv1/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block6_sepconv1/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_14), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv1_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block6_sepconv1_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_14), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv1_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block6_sepconv1_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_10), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv2/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block6_sepconv2/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_10), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv2/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block6_sepconv2/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_15), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv2_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block6_sepconv2_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_15), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv2_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block6_sepconv2_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_11), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv3/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block6_sepconv3/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_11), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv3/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block6_sepconv3/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_16), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv3_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block6_sepconv3_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_16), but
# are not present in its tracked objects:
#   <tf.Variable 'block6_sepconv3_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block6_sepconv3_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_12), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv1/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block7_sepconv1/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_12), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv1/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block7_sepconv1/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_17), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv1_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block7_sepconv1_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_17), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv1_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block7_sepconv1_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_13), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv2/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block7_sepconv2/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_13), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv2/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block7_sepconv2/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_18), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv2_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block7_sepconv2_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_18), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv2_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block7_sepconv2_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_14), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv3/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block7_sepconv3/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_14), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv3/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block7_sepconv3/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_19), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv3_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block7_sepconv3_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_19), but
# are not present in its tracked objects:
#   <tf.Variable 'block7_sepconv3_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block7_sepconv3_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_15), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv1/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block8_sepconv1/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_15), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv1/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block8_sepconv1/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_20), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv1_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block8_sepconv1_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_20), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv1_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block8_sepconv1_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_16), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv2/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block8_sepconv2/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_16), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv2/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block8_sepconv2/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_21), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv2_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block8_sepconv2_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_21), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv2_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block8_sepconv2_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_17), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv3/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block8_sepconv3/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_17), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv3/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block8_sepconv3/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_22), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv3_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block8_sepconv3_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_22), but
# are not present in its tracked objects:
#   <tf.Variable 'block8_sepconv3_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block8_sepconv3_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_18), but
# are not present in its tracked objects:
#   <tf.Variable 'block9_sepconv1/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block9_sepconv1/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.separable_conv2d_18), but
# are not present in its tracked objects:
#   <tf.Variable 'block9_sepconv1/depthwise_kernel:0' shape=(3, 3, 728, 1) dtype=float32>
#   <tf.Variable 'block9_sepconv1/pointwise_kernel:0' shape=(1, 1, 728, 728) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_23), but
# are not present in its tracked objects:
#   <tf.Variable 'block9_sepconv1_bn/gamma:0' shape=(728,) dtype=float32>
#   <tf.Variable 'block9_sepconv1_bn/beta:0' shape=(728,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# ...
# tf.nn.relu_14 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_14[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_15 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_15[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_16 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_16[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_17 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_17[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_18 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_18[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_19 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_6[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_19[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_20 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_20[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_21 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_21[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_6[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_22 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_22[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_23 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_23[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_24 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_24[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_8 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_25 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_8[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_25[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_26 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_26[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_27 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_27[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_9 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_8[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_28 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_9[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_28[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_29 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_29[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_30 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_30[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_10 (TFOpLa (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_9[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_31 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_31[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_32 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 1024)   0           tf.nn.relu_32[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 1024), 0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.convolution_5 (TFOpLambda (None, 5, 5, 1024)   0           tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.max_pool_3 (TFO (None, 5, 5, 1024)   0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 5, 5, 1024), 0           tf.nn.convolution_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_11 (TFOpLa (None, 5, 5, 1024)   0           tf.compat.v1.nn.max_pool_3[0][0]
#                                                                  tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 5, 5, 1536)   0           tf.__operators__.add_11[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 5, 5, 1536), 0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_33 (TFOpLambda)      (None, 5, 5, 1536)   0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 5, 5, 2048)   0           tf.nn.relu_33[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 5, 5, 2048), 0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_34 (TFOpLambda)      (None, 5, 5, 2048)   0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           tf.nn.relu_34[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            2049        dropout[0][0]
# ==================================================================================================
# Total params: 2,049
# Trainable params: 2,049
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### 5. Build the larger model that includes the pre-trained part and prepare it for training.
#
# * Show the model summary so you are sure which components are included and how many (un)trainable parameters you have

# %%
model.summary()

# %% [markdown]
# ### 6. Train the trainable part of the model

# %%
model.compile(
  optimizer=keras.optimizers.Adam(learning_rate=0.001),
  loss=keras.losses.BinaryCrossentropy(from_logits=True),
  metrics=[keras.metrics.BinaryAccuracy()],
)

epochs = 100
history = model.fit(train_ds, epochs=epochs, validation_data=validation_ds)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 55s 562ms/step - loss: 3.7824 - binary_accuracy: 0.5830 - val_loss: 2.3267 - val_binary_accuracy: 0.6311
# Epoch 2/100
# 13/13 [==============================] - 2s 184ms/step - loss: 2.6208 - binary_accuracy: 0.6085 - val_loss: 2.4108 - val_binary_accuracy: 0.6214
# Epoch 3/100
# 13/13 [==============================] - 2s 184ms/step - loss: 2.5270 - binary_accuracy: 0.6343 - val_loss: 1.4978 - val_binary_accuracy: 0.7087
# Epoch 4/100
# 13/13 [==============================] - 2s 184ms/step - loss: 1.9376 - binary_accuracy: 0.6852 - val_loss: 1.0635 - val_binary_accuracy: 0.7184
# Epoch 5/100
# 13/13 [==============================] - 2s 185ms/step - loss: 1.7510 - binary_accuracy: 0.6694 - val_loss: 0.8280 - val_binary_accuracy: 0.7379
# Epoch 6/100
# 13/13 [==============================] - 2s 185ms/step - loss: 1.4976 - binary_accuracy: 0.7069 - val_loss: 1.2844 - val_binary_accuracy: 0.7573
# Epoch 7/100
# 13/13 [==============================] - 2s 184ms/step - loss: 1.3373 - binary_accuracy: 0.7573 - val_loss: 0.6718 - val_binary_accuracy: 0.7670
# Epoch 8/100
# Epoch 98/100
# 13/13 [==============================] - 2s 185ms/step - loss: 0.1762 - binary_accuracy: 0.9339 - val_loss: 0.2528 - val_binary_accuracy: 0.8835
# Epoch 99/100
# 13/13 [==============================] - 2s 184ms/step - loss: 0.2481 - binary_accuracy: 0.9043 - val_loss: 0.4161 - val_binary_accuracy: 0.8544
# Epoch 100/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2173 - binary_accuracy: 0.8993 - val_loss: 0.5099 - val_binary_accuracy: 0.8544

# %%
score = model.evaluate(test_ds)
print('Val Loss:', score[0])
print('Val accuracy:', score[1])
# Out:
# 4/4 [==============================] - 1s 329ms/step - loss: 0.3459 - binary_accuracy: 0.9216
# Val Loss: 0.3458656370639801
# Val accuracy: 0.9215686321258545

# %% [markdown]
# ### 7. Show the training plots and confusion matrix

# %%
# Training history
_, axes = plt.subplots(2, 1, sharex=True)
# ax1.ylabel('training error')
# ax1.xlabel('epoch')
for ax, k in zip(axes, history.history.keys()):
    ax.set_ylabel(k)
    ax.set_xlabel("Epoch")
    ax.plot(history.history[k], label = k)
# plt.legend(loc='best')
plt.tight_layout()

# %%
# The confusion matrix is visualized 
from sklearn.metrics import confusion_matrix
import seaborn as sns

result = model.predict(test_ds, steps = 10)

pred = list()
for entry in result:
  if entry>0:
    pred.append(1)
  else:
    pred.append(0)

cm = confusion_matrix(test_labels, pred)

sns.heatmap(cm, annot=True)
# Out:
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 10 batches). You may need to use the repeat() function when building your dataset.
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 10 batches). You may need to use the repeat() function when building your dataset.

# %% [markdown]
# ### 8. Finetune the model and show the plots, test data confusion matrix and accuracy.

# %%
base_model.trainable = True
model.summary()

model.compile(
  optimizer=keras.optimizers.Adam(1e-5),  # Low learning rate
  loss=keras.losses.BinaryCrossentropy(from_logits=True),
  metrics=[keras.metrics.BinaryAccuracy()],
)

epochs = 100
history = model.fit(train_ds, epochs=epochs, validation_data=validation_ds)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 150, 150, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor (TFOpLambd (None, 150, 150, 3)  0           sequential[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 150, 150, 3)  0           tf.convert_to_tensor[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv (TFOpLambda)    (None, 150, 150, 3)  0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution (TFOpLambda)  (None, 74, 74, 32)   0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 74, 74, 32), 0           tf.nn.convolution[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (None, 74, 74, 32)   0           tf.compat.v1.nn.fused_batch_norm[
# __________________________________________________________________________________________________
# tf.nn.convolution_1 (TFOpLambda (None, 72, 72, 64)   0           tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 72, 72, 64), 0           tf.nn.convolution_1[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_1 (TFOpLambda)       (None, 72, 72, 64)   0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 72, 72, 128)  0           tf.nn.relu_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 72, 72, 128) 0           tf.compat.v1.nn.separable_conv2d[
# __________________________________________________________________________________________________
# tf.nn.relu_2 (TFOpLambda)       (None, 72, 72, 128)  0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 72, 72, 128)  0           tf.nn.relu_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 72, 72, 128) 0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.convolution_2 (TFOpLambda (None, 36, 36, 128)  0           tf.nn.relu_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.max_pool (TFOpL (None, 36, 36, 128)  0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 36, 36, 128) 0           tf.nn.convolution_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 36, 36, 128)  0           tf.compat.v1.nn.max_pool[0][0]
#                                                                  tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.nn.relu_3 (TFOpLambda)       (None, 36, 36, 128)  0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 36, 36, 256)  0           tf.nn.relu_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 36, 36, 256) 0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_4 (TFOpLambda)       (None, 36, 36, 256)  0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 36, 36, 256)  0           tf.nn.relu_4[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 36, 36, 256) 0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.convolution_3 (TFOpLambda (None, 18, 18, 256)  0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.max_pool_1 (TFO (None, 18, 18, 256)  0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 18, 18, 256) 0           tf.nn.convolution_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 18, 18, 256)  0           tf.compat.v1.nn.max_pool_1[0][0]
#                                                                  tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.nn.relu_5 (TFOpLambda)       (None, 18, 18, 256)  0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 18, 18, 728)  0           tf.nn.relu_5[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 18, 18, 728) 0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_6 (TFOpLambda)       (None, 18, 18, 728)  0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 18, 18, 728)  0           tf.nn.relu_6[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 18, 18, 728) 0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.convolution_4 (TFOpLambda (None, 9, 9, 728)    0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.max_pool_2 (TFO (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.nn.convolution_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.max_pool_2[0][0]
#                                                                  tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.nn.relu_7 (TFOpLambda)       (None, 9, 9, 728)    0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_7[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_8 (TFOpLambda)       (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_8[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_9 (TFOpLambda)       (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_9[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_10 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_10[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_11 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_11[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_12 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_12[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_13 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_13[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_14 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_14[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_15 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_15[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_16 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_16[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_17 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_17[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_18 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_18[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_19 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_6[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_19[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_20 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_20[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_21 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_21[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_6[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_22 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_22[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_23 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_23[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_24 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_24[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_8 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_25 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_8[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_25[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_26 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_26[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_27 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_27[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_9 (TFOpLam (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_8[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_28 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_9[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_28[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_29 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_29[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_30 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_30[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.__operators__.add_10 (TFOpLa (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.__operators__.add_9[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_31 (TFOpLambda)      (None, 9, 9, 728)    0           tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 728)    0           tf.nn.relu_31[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 728),  0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_32 (TFOpLambda)      (None, 9, 9, 728)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 9, 9, 1024)   0           tf.nn.relu_32[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 9, 9, 1024), 0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.convolution_5 (TFOpLambda (None, 5, 5, 1024)   0           tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.max_pool_3 (TFO (None, 5, 5, 1024)   0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 5, 5, 1024), 0           tf.nn.convolution_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_11 (TFOpLa (None, 5, 5, 1024)   0           tf.compat.v1.nn.max_pool_3[0][0]
#                                                                  tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 5, 5, 1536)   0           tf.__operators__.add_11[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 5, 5, 1536), 0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_33 (TFOpLambda)      (None, 5, 5, 1536)   0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.compat.v1.nn.separable_conv2 (None, 5, 5, 2048)   0           tf.nn.relu_33[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 5, 5, 2048), 0           tf.compat.v1.nn.separable_conv2d_
# __________________________________________________________________________________________________
# tf.nn.relu_34 (TFOpLambda)      (None, 5, 5, 2048)   0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           tf.nn.relu_34[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            2049        dropout[0][0]
# ==================================================================================================
# Total params: 2,049
# Trainable params: 2,049
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 11s 378ms/step - loss: 0.2965 - binary_accuracy: 0.8832 - val_loss: 0.4423 - val_binary_accuracy: 0.8738
# Epoch 2/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2367 - binary_accuracy: 0.9280 - val_loss: 0.4022 - val_binary_accuracy: 0.8738
# Epoch 3/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.2107 - binary_accuracy: 0.9151 - val_loss: 0.3766 - val_binary_accuracy: 0.8738
# Epoch 4/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.1641 - binary_accuracy: 0.9492 - val_loss: 0.3577 - val_binary_accuracy: 0.8932
# Epoch 5/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2558 - binary_accuracy: 0.9092 - val_loss: 0.3459 - val_binary_accuracy: 0.8932
# Epoch 6/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2215 - binary_accuracy: 0.9166 - val_loss: 0.3432 - val_binary_accuracy: 0.8835
# Epoch 7/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.1651 - binary_accuracy: 0.9116 - val_loss: 0.3360 - val_binary_accuracy: 0.8835
# Epoch 8/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.1841 - binary_accuracy: 0.9204 - val_loss: 0.3303 - val_binary_accuracy: 0.8835
# Epoch 9/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.1935 - binary_accuracy: 0.9094 - val_loss: 0.3301 - val_binary_accuracy: 0.8835
# Epoch 10/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2468 - binary_accuracy: 0.8847 - val_loss: 0.3236 - val_binary_accuracy: 0.8835
# Epoch 11/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.1822 - binary_accuracy: 0.9110 - val_loss: 0.3175 - val_binary_accuracy: 0.8835
# Epoch 12/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.1980 - binary_accuracy: 0.9189 - val_loss: 0.3146 - val_binary_accuracy: 0.8835
# Epoch 13/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.1937 - binary_accuracy: 0.8998 - val_loss: 0.3144 - val_binary_accuracy: 0.8835
# Epoch 14/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2239 - binary_accuracy: 0.9153 - val_loss: 0.3093 - val_binary_accuracy: 0.8835
# Epoch 15/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2055 - binary_accuracy: 0.8752 - val_loss: 0.3102 - val_binary_accuracy: 0.8835
# Epoch 16/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.1714 - binary_accuracy: 0.9274 - val_loss: 0.3087 - val_binary_accuracy: 0.8835
# Epoch 17/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.1894 - binary_accuracy: 0.8875 - val_loss: 0.3141 - val_binary_accuracy: 0.8835
# Epoch 18/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.1781 - binary_accuracy: 0.9370 - val_loss: 0.3167 - val_binary_accuracy: 0.8932
# Epoch 19/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.1974 - binary_accuracy: 0.9057 - val_loss: 0.3084 - val_binary_accuracy: 0.8835
# Epoch 20/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.1945 - binary_accuracy: 0.9122 - val_loss: 0.3042 - val_binary_accuracy: 0.8835
# Epoch 21/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2281 - binary_accuracy: 0.9041 - val_loss: 0.2992 - val_binary_accuracy: 0.8835
# Epoch 22/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2357 - binary_accuracy: 0.9201 - val_loss: 0.2984 - val_binary_accuracy: 0.8835
# Epoch 23/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.3100 - binary_accuracy: 0.8909 - val_loss: 0.3013 - val_binary_accuracy: 0.8835
# Epoch 24/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2774 - binary_accuracy: 0.8796 - val_loss: 0.3054 - val_binary_accuracy: 0.8835
# Epoch 25/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.1976 - binary_accuracy: 0.9132 - val_loss: 0.3081 - val_binary_accuracy: 0.8932
# Epoch 26/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.1531 - binary_accuracy: 0.9506 - val_loss: 0.3059 - val_binary_accuracy: 0.8835
# Epoch 27/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2172 - binary_accuracy: 0.8969 - val_loss: 0.3080 - val_binary_accuracy: 0.8932
# Epoch 28/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2153 - binary_accuracy: 0.9020 - val_loss: 0.3072 - val_binary_accuracy: 0.8932
# Epoch 29/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2018 - binary_accuracy: 0.9252 - val_loss: 0.3107 - val_binary_accuracy: 0.8932
# Epoch 30/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2669 - binary_accuracy: 0.9105 - val_loss: 0.3145 - val_binary_accuracy: 0.9029
# Epoch 31/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2531 - binary_accuracy: 0.9073 - val_loss: 0.3184 - val_binary_accuracy: 0.9029
# Epoch 32/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2385 - binary_accuracy: 0.9070 - val_loss: 0.3218 - val_binary_accuracy: 0.9029
# Epoch 33/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2043 - binary_accuracy: 0.8696 - val_loss: 0.3246 - val_binary_accuracy: 0.9029
# Epoch 34/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2749 - binary_accuracy: 0.8845 - val_loss: 0.3208 - val_binary_accuracy: 0.9029
# Epoch 35/100
# 13/13 [==============================] - 2s 185ms/step - loss: 0.2134 - binary_accuracy: 0.9054 - val_loss: 0.3170 - val_binary_accuracy: 0.9029
# Epoch 36/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2302 - binary_accuracy: 0.9104 - val_loss: 0.3158 - val_binary_accuracy: 0.9029
# Epoch 37/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2110 - binary_accuracy: 0.9001 - val_loss: 0.3137 - val_binary_accuracy: 0.9029
# Epoch 38/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.1395 - binary_accuracy: 0.9443 - val_loss: 0.3091 - val_binary_accuracy: 0.8835
# Epoch 39/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2012 - binary_accuracy: 0.9002 - val_loss: 0.3044 - val_binary_accuracy: 0.8835
# Epoch 40/100
# 13/13 [==============================] - 2s 185ms/step - loss: 0.2526 - binary_accuracy: 0.9092 - val_loss: 0.2982 - val_binary_accuracy: 0.8835
# Epoch 41/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.1620 - binary_accuracy: 0.9248 - val_loss: 0.3023 - val_binary_accuracy: 0.8835
# Epoch 42/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2512 - binary_accuracy: 0.9159 - val_loss: 0.3024 - val_binary_accuracy: 0.8835
# Epoch 43/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2097 - binary_accuracy: 0.8942 - val_loss: 0.2991 - val_binary_accuracy: 0.8835
# Epoch 44/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2358 - binary_accuracy: 0.9002 - val_loss: 0.3028 - val_binary_accuracy: 0.8932
# Epoch 45/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2235 - binary_accuracy: 0.9075 - val_loss: 0.3018 - val_binary_accuracy: 0.8932
# Epoch 46/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2538 - binary_accuracy: 0.8980 - val_loss: 0.2971 - val_binary_accuracy: 0.8932
# Epoch 47/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.1800 - binary_accuracy: 0.9135 - val_loss: 0.2967 - val_binary_accuracy: 0.8932
# Epoch 48/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2472 - binary_accuracy: 0.8902 - val_loss: 0.3023 - val_binary_accuracy: 0.9029
# Epoch 49/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2105 - binary_accuracy: 0.9125 - val_loss: 0.2968 - val_binary_accuracy: 0.8932
# Epoch 50/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.1866 - binary_accuracy: 0.9184 - val_loss: 0.2987 - val_binary_accuracy: 0.9029
# Epoch 51/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2366 - binary_accuracy: 0.8900 - val_loss: 0.3023 - val_binary_accuracy: 0.9029
# Epoch 52/100
# 13/13 [==============================] - 2s 190ms/step - loss: 0.1803 - binary_accuracy: 0.9238 - val_loss: 0.2988 - val_binary_accuracy: 0.9029
# Epoch 53/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.1896 - binary_accuracy: 0.9202 - val_loss: 0.3018 - val_binary_accuracy: 0.9029
# Epoch 54/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.1763 - binary_accuracy: 0.9365 - val_loss: 0.3041 - val_binary_accuracy: 0.8932
# Epoch 55/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2169 - binary_accuracy: 0.9280 - val_loss: 0.3046 - val_binary_accuracy: 0.8932
# Epoch 56/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2258 - binary_accuracy: 0.8881 - val_loss: 0.3120 - val_binary_accuracy: 0.9029
# Epoch 57/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2392 - binary_accuracy: 0.8950 - val_loss: 0.3139 - val_binary_accuracy: 0.9029
# Epoch 58/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2269 - binary_accuracy: 0.9203 - val_loss: 0.3129 - val_binary_accuracy: 0.9029
# Epoch 59/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2499 - binary_accuracy: 0.9162 - val_loss: 0.3064 - val_binary_accuracy: 0.8932
# Epoch 60/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2576 - binary_accuracy: 0.9023 - val_loss: 0.3014 - val_binary_accuracy: 0.8835
# Epoch 61/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.1920 - binary_accuracy: 0.9174 - val_loss: 0.3040 - val_binary_accuracy: 0.8932
# Epoch 62/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2144 - binary_accuracy: 0.9066 - val_loss: 0.3052 - val_binary_accuracy: 0.8932
# Epoch 63/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2478 - binary_accuracy: 0.8928 - val_loss: 0.3005 - val_binary_accuracy: 0.8835
# Epoch 64/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2717 - binary_accuracy: 0.9096 - val_loss: 0.2995 - val_binary_accuracy: 0.8932
# Epoch 65/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2091 - binary_accuracy: 0.8974 - val_loss: 0.3001 - val_binary_accuracy: 0.8932
# Epoch 66/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.1596 - binary_accuracy: 0.9482 - val_loss: 0.3029 - val_binary_accuracy: 0.8932
# Epoch 67/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2130 - binary_accuracy: 0.9121 - val_loss: 0.3055 - val_binary_accuracy: 0.8932
# Epoch 68/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2507 - binary_accuracy: 0.8910 - val_loss: 0.3115 - val_binary_accuracy: 0.9029
# Epoch 69/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2386 - binary_accuracy: 0.9138 - val_loss: 0.3134 - val_binary_accuracy: 0.9029
# Epoch 70/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.1962 - binary_accuracy: 0.9170 - val_loss: 0.3064 - val_binary_accuracy: 0.8932
# Epoch 71/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2336 - binary_accuracy: 0.8994 - val_loss: 0.3056 - val_binary_accuracy: 0.8932
# Epoch 72/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.1932 - binary_accuracy: 0.9183 - val_loss: 0.3012 - val_binary_accuracy: 0.8932
# Epoch 73/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.1740 - binary_accuracy: 0.9102 - val_loss: 0.3048 - val_binary_accuracy: 0.8932
# Epoch 74/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2178 - binary_accuracy: 0.8940 - val_loss: 0.3059 - val_binary_accuracy: 0.8932
# Epoch 75/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.2265 - binary_accuracy: 0.9274 - val_loss: 0.3077 - val_binary_accuracy: 0.8932
# Epoch 76/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2907 - binary_accuracy: 0.8596 - val_loss: 0.3068 - val_binary_accuracy: 0.8932
# Epoch 77/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2123 - binary_accuracy: 0.9033 - val_loss: 0.3092 - val_binary_accuracy: 0.8932
# Epoch 78/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2158 - binary_accuracy: 0.9095 - val_loss: 0.3037 - val_binary_accuracy: 0.8932
# Epoch 79/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.1928 - binary_accuracy: 0.9173 - val_loss: 0.3005 - val_binary_accuracy: 0.8932
# Epoch 80/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2092 - binary_accuracy: 0.9212 - val_loss: 0.3038 - val_binary_accuracy: 0.8932
# Epoch 81/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2209 - binary_accuracy: 0.9316 - val_loss: 0.3024 - val_binary_accuracy: 0.8932
# Epoch 82/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.1798 - binary_accuracy: 0.9376 - val_loss: 0.2974 - val_binary_accuracy: 0.8932
# Epoch 83/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2440 - binary_accuracy: 0.9256 - val_loss: 0.2950 - val_binary_accuracy: 0.8932
# Epoch 84/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2031 - binary_accuracy: 0.9376 - val_loss: 0.2997 - val_binary_accuracy: 0.8835
# Epoch 85/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.2076 - binary_accuracy: 0.8991 - val_loss: 0.3021 - val_binary_accuracy: 0.8932
# Epoch 86/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2641 - binary_accuracy: 0.8844 - val_loss: 0.3032 - val_binary_accuracy: 0.8932
# Epoch 87/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.1782 - binary_accuracy: 0.9171 - val_loss: 0.3076 - val_binary_accuracy: 0.9029
# Epoch 88/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.1808 - binary_accuracy: 0.9410 - val_loss: 0.3099 - val_binary_accuracy: 0.9029
# Epoch 89/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.1853 - binary_accuracy: 0.9394 - val_loss: 0.3053 - val_binary_accuracy: 0.9029
# Epoch 90/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2242 - binary_accuracy: 0.9230 - val_loss: 0.3018 - val_binary_accuracy: 0.8932
# Epoch 91/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2664 - binary_accuracy: 0.9033 - val_loss: 0.2971 - val_binary_accuracy: 0.9029
# Epoch 92/100
# 13/13 [==============================] - 3s 202ms/step - loss: 0.1932 - binary_accuracy: 0.9069 - val_loss: 0.3005 - val_binary_accuracy: 0.8932
# Epoch 93/100
# 13/13 [==============================] - 2s 192ms/step - loss: 0.2045 - binary_accuracy: 0.9175 - val_loss: 0.2994 - val_binary_accuracy: 0.8932
# Epoch 94/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.2096 - binary_accuracy: 0.8938 - val_loss: 0.3057 - val_binary_accuracy: 0.8932
# Epoch 95/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.2183 - binary_accuracy: 0.9132 - val_loss: 0.3119 - val_binary_accuracy: 0.9029
# Epoch 96/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.1907 - binary_accuracy: 0.9047 - val_loss: 0.3041 - val_binary_accuracy: 0.8932
# Epoch 97/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.1949 - binary_accuracy: 0.9279 - val_loss: 0.2955 - val_binary_accuracy: 0.9029
# Epoch 98/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.2100 - binary_accuracy: 0.9035 - val_loss: 0.2937 - val_binary_accuracy: 0.9029
# Epoch 99/100
# 13/13 [==============================] - 2s 188ms/step - loss: 0.2413 - binary_accuracy: 0.9023 - val_loss: 0.2923 - val_binary_accuracy: 0.9029
# Epoch 100/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.2070 - binary_accuracy: 0.9174 - val_loss: 0.2915 - val_binary_accuracy: 0.9029

# %%
score = model.evaluate(test_ds)
print('Val Loss:', score[0])
print('Val accuracy:', score[1])
# Out:
# 4/4 [==============================] - 0s 104ms/step - loss: 0.1962 - binary_accuracy: 0.9510
# Val Loss: 0.19620028138160706
# Val accuracy: 0.9509803652763367

# %%
# The finetuned training plots are visualized
# Training history
_, axes = plt.subplots(2, 1, sharex=True)
# ax1.ylabel('training error')
# ax1.xlabel('epoch')
for ax, k in zip(axes, history.history.keys()):
    ax.set_ylabel(k)
    ax.set_xlabel("Epoch")
    ax.plot(history.history[k], label = k)
# plt.legend(loc='best')
plt.tight_layout()

# %%
# The finetuned confusion matrix is visualized 

finetuned_result = model.predict(test_ds, steps = 10)

finetuned_pred = list()
for entry in finetuned_result:
  if entry>0:
    finetuned_pred.append(1)
  else:
    finetuned_pred.append(0)

finetuned_cm = confusion_matrix(test_labels, finetuned_pred)

sns.heatmap(finetuned_cm, annot=True)
# Out:
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 10 batches). You may need to use the repeat() function when building your dataset.
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 10 batches). You may need to use the repeat() function when building your dataset.

# %% [markdown]
# ### 9. Comment on the results. Are the results to your satisfaction? Which phase contributed to the improved performance? What was the most challenging aspect of the exercise? Ideas for improving the model?

# %% [markdown]
# Answer:
# The model is able to predict whether the image is a horse or a human in 94% of the cases. I Find this highly satisfactory.
#
# The model was build and trained using the Adam optimization, where we went from an accuracy of 0.63 to 0.92 over 300 epocs.
# The additional finetning improved the model from an accuracy of 0.92 to 0.95.
#
# I found it very hard to work with the tensorflow-data format, leading to datahandling being quite time consuming and difficult.
#
# In order to improve the model the image data augmentation could be optimized and other network structures could be tested.
