# %%
#!/usr/bin/env python3
 
##########################################################
# Copyright (c) Jesper Vang <jesper_vang@me.com>         #
# Created on 3 Aug 2021                                 #
# Version:	0.0.1                                        #
# What: ? 						                         #
##########################################################

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn
from sklearn import datasets
print("Pandas Version: {}".format(pd.__version__))
print("Numpy Version: {}".format(np.__version__))
print("Matplotlib Version: {}".format(matplotlib.__version__))
print("Scikit-learn Version: {}".format(sklearn.__version__))
print("Seaborn Version: {}".format(sns.__version__))
np.set_printoptions(suppress=True, linewidth=130)

# needed for facets 
from IPython.core.display import display, HTML

# Where to save the figures
print(f'the current path is: {os.getcwd()}')
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
# Out:
# Pandas Version: 1.3.0
# Numpy Version: 1.19.5
# Matplotlib Version: 3.4.2
# Scikit-learn Version: 0.24.2
# Seaborn Version: 0.11.1
# the current path is: /Users/jvang/Documents/Projects/Applied_AI_IT_Uni

# %%
df = pd.read_csv("day02/USA_Housing.csv")
df.columns.to_list();
df = df.rename(columns=
{'Avg. Area Income':'Income',
 'Avg. Area House Age':'Age',
 'Avg. Area Number of Rooms':'Room',
 'Avg. Area Number of Bedrooms':'Bedrooms',
 'Area Population':'Population',
 'Price':'Price'});
df = df.drop(['Address'], axis=1).round(3)

# %%
df.head()
# Out:
#       Income    Age   Room  Bedrooms  Population        Price
# 0  79545.459  5.683  7.009      4.09   23086.801  1059033.558
# 1  79248.642  6.003  6.731      3.09   40173.072  1505890.915
# 2  61287.067  5.866  8.513      5.13   36882.159  1058987.988
# 3  63345.240  7.188  5.587      3.26   34310.243  1260616.807
# 4  59982.197  5.041  7.839      4.23   26354.109   630943.489

# %%
from sklearn.model_selection import train_test_split

# array = df.values
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
# 
# X = array[:, :-1]
# y = array[:, -1]


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=997
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4000, 5)
# (1000, 5)
# (4000,)
# (1000,)

# %%
jsonstr = X_train.to_json(orient='records')
HTML_TEMPLATE = """
<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
<facets-dive id="elem" height="600"></facets-dive>
<script>
var data = {jsonstr};
document.querySelector("#elem").data = data;
</script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
# <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
# <facets-dive id="elem" height="600"></facets-dive>
# <script>
# var data = [{"Income":71784.016,"Age":4.791,"Room":6.695,"Bedrooms":4.26,"Population":15554.284},{"Income":76309.495,"Age":6.07,"Room":7.669,"Bedrooms":4.09,"Population":42652.367},{"Income":64882.156,"Age":4.899,"Room":7.569,"Bedrooms":6.05,"Population":32807.854},{"Income":91024.417,"Age":5.832,"Room":7.628,"Bedrooms":5.24,"Population":44381.268},{"Income":74533.162,"Age":6.679,"Room":5.919,"Bedrooms":4.0,"Population