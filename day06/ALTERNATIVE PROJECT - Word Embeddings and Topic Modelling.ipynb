# %% [markdown]
# # Project: processing your own corpus

# %% [markdown]
# As an alternative to the original project, we will give you the freedom to process your own corpus. Please provide, in this notebook, a report on:
#
# 1. What your data is and, if it is relevant, how you scraped it.
# 2. What the results are of embedding their tokens using `word2vec`.
# 3. What the topics are (using `lda`), and how you went around interpreting them.
#
# Include code alongside your text.
